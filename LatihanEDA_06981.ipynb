# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.head()
# Out:
#    R233 Soekarno  Tesla Invander 3  Druga Foxy  Hexohm Jenis
# 0           12.0               4.0        10.0    15.0   Mod
# 1            8.0               8.0         5.0     7.0   Mod
# 2            6.0               7.0         1.0     5.0   Mod
# 3            7.0               9.0        13.0    12.0   Mod
# 4           10.0              12.0         6.0     8.0   Mod

# %%
iris.plot(x='R233 Soekarno', y='Tesla Invander 3')
# Out:
# <AxesSubplot:xlabel='R233 Soekarno'>
